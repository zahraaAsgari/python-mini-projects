# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dubai_properties.csv',encoding= 'utf-8')

# %%
df.head()
# Out:
#                                              Address    Rent  Beds  Baths  \
# 0  The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2            Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3  Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                    West Yas, Yas Island, Abu Dhabi  350000     5      7
#
#         Type  Area_in_sqft  Rent_per_sqft Rent_category Frequency  \
# 0  Apartment          1785      69.467787        Medium    Yearly
# 1  Apartment          1422      98.452883        Medium    Yearly
# 2  Apartment          1314      75.342466        Medium    Yearly
# 3  Penthouse          3843      57.246942          High    Yearly
# 4      Villa          6860      51.020408          High    Yearly
#
#     Furnishing   Purpose Posted_date  Age_of_listing_in_days        Location  \
# ...

# %%
df.describe()
# Out:
#                Rent          Beds         Baths   Area_in_sqft  Rent_per_sqft  \
# count  7.374200e+04  73742.000000  73742.000000   73742.000000   73742.000000
# mean   1.479250e+05      2.162811      2.650213    2054.053552      88.057754
# std    3.069658e+05      1.578155      1.632997    3003.919252      66.534400
# min    0.000000e+00      0.000000      1.000000      74.000000       0.000000
# 25%    5.499900e+04      1.000000      2.000000     850.000000      39.977778
# 50%    9.800000e+04      2.000000      2.000000    1334.000000      71.428571
# 75%    1.700000e+05      3.000000      3.000000    2130.000000     118.483412
# max    5.500000e+07     12.000000     11.000000  210254.000000    2182.044888
#
#        Age_of_listing_in_days      Latitude     Longitude
# count            73742.000000  73023.000000  73023.000000
# mean                74.261547     24.918929     55.053133
# std                 72.346767      0.569356      0.653722
# ...

# %%
df.shape
# Out:
# (73742, 17)

# %%
X = df[["Beds", "Area_in_sqft", "Baths"]]
y = df["Rent"]

# %%
X.head()
# Out:
#    Beds  Area_in_sqft  Baths
# 0     3          1785      4
# 1     3          1422      4
# 2     2          1314      3
# 3     3          3843      4
# 4     5          6860      7

# %%
y.head()
# Out:
# 0    124000
# 1    140000
# 2     99000
# 3    220000
# 4    350000
# Name: Rent, dtype: int64

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=45 , test_size=0.2)

# %%
X_train.shape
# Out:
# (58993, 3)

# %%
X_test.shape
# Out:
# (14749, 3)

# %%
y_train.shape
# Out:
# (58993,)

# %%
y_test.shape
# Out:
# (14749,)

# %%
X_train.head()
# Out:
#        Beds  Area_in_sqft  Baths
# 7554      2          1399      3
# 55001     0           406      2
# 20691     0           590      1
# 30243     2          2168      2
# 18506     2          1600      3

# %%
X_train.describe()
# Out:
#                Beds   Area_in_sqft         Baths
# count  58993.000000   58993.000000  58993.000000
# mean       2.161426    2049.298612      2.649687
# std        1.579067    2871.311273      1.634552
# min        0.000000      74.000000      1.000000
# 25%        1.000000     850.000000      2.000000
# 50%        2.000000    1332.000000      2.000000
# 75%        3.000000    2142.000000      3.000000
# max       12.000000  173565.000000     11.000000

# %%
X_test.describe()
# Out:
#                Beds   Area_in_sqft         Baths
# count  14749.000000   14749.000000  14749.000000
# mean       2.168350    2073.072344      2.652315
# std        1.574542    3484.264676      1.626817
# min        0.000000      74.000000      1.000000
# 25%        1.000000     850.000000      2.000000
# 50%        2.000000    1337.000000      2.000000
# 75%        3.000000    2100.000000      3.000000
# max       11.000000  210254.000000     11.000000

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X1=df[["Beds","Baths","Area_in_sqft","Rent_per_sqft","Age_of_listing_in_days"]]
cols = X1.columns

# %%
scaler=StandardScaler()
X1_standard=scaler.fit_transform(X1)

# %%
X1_standard=pd.DataFrame(X1_standard,columns=cols)
X1_standard.head()
# Out:
#        Beds     Baths  Area_in_sqft  Rent_per_sqft  Age_of_listing_in_days
# 0  0.530490  0.826576     -0.089568      -0.279406               -0.404465
# 1  0.530490  0.826576     -0.210411       0.156238               -0.418288
# 2 -0.103166  0.214201     -0.246364      -0.191110               -0.597979
# 3  0.530490  0.826576      0.595542      -0.463084               -0.238596
# 4  1.797801  2.663702      1.599903      -0.556668               -0.128017

# %%
X1_standard.describe().round(3)
# Out:
#             Beds      Baths  Area_in_sqft  Rent_per_sqft  \
# count  73742.000  73742.000     73742.000      73742.000
# mean      -0.000      0.000         0.000          0.000
# std        1.000      1.000         1.000          1.000
# min       -1.370     -1.011        -0.659         -1.324
# 25%       -0.737     -0.398        -0.401         -0.723
# 50%       -0.103     -0.398        -0.240         -0.250
# 75%        0.530      0.214         0.025          0.457
# max        6.233      5.113        69.310         31.472
#
#        Age_of_listing_in_days
# count               73742.000
# mean                    0.000
# std                     1.000
# min                    -0.874
# 25%                    -0.612
# 50%                    -0.308
# 75%                     0.287
# max                    30.433

# %%
min_max_scaler=MinMaxScaler(feature_range=(0,1))
X1_normalaize=min_max_scaler.fit_transform(X1)
X1_normalaize=pd.DataFrame(X1_normalaize,columns=cols)

# %%
X1_normalaize.head()
# Out:
#        Beds  Baths  Area_in_sqft  Rent_per_sqft  Age_of_listing_in_days
# 0  0.250000    0.3      0.008141       0.031836                0.015011
# 1  0.250000    0.3      0.006414       0.045120                0.014570
# 2  0.166667    0.2      0.005900       0.034528                0.008830
# 3  0.250000    0.3      0.017932       0.026235                0.020309
# 4  0.416667    0.6      0.032287       0.023382                0.023841

# %%
X1_normalaize.describe().round(3)
# Out:
#             Beds      Baths  Area_in_sqft  Rent_per_sqft  \
# count  73742.000  73742.000     73742.000      73742.000
# mean       0.180      0.165         0.009          0.040
# std        0.132      0.163         0.014          0.030
# min        0.000      0.000         0.000          0.000
# 25%        0.083      0.100         0.004          0.018
# 50%        0.167      0.100         0.006          0.033
# 75%        0.250      0.200         0.010          0.054
# max        1.000      1.000         1.000          1.000
#
#        Age_of_listing_in_days
# count               73742.000
# mean                    0.028
# std                     0.032
# min                     0.000
# 25%                     0.008
# 50%                     0.018
# 75%                     0.037
# max                     1.000
